# %%
from numpy import random
x=random.normal(size=(2,3))
print(x)
# Out:
# [[-2.09250719  0.75617619 -0.15687853]
#  [ 2.179947    1.60313678 -1.0231403 ]]

# %%
x=random.normal(loc=1,scale=2, size=(2,3))
print(x)
# Out:
# [[ 2.20727851  2.09954189  4.55576709]
#  [ 0.64280346  0.56983436 -1.09559723]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(random.normal(size=100),kde=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.kdeplot(random.normal(size=100))
plt.show()
